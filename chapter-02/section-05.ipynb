# %% [markdown]
# # 处理多个序列 (PyTorch)

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
# !pip install datasets evaluate transformers[sentencepiece]

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

checkpoint = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSequenceClassification.from_pretrained(checkpoint)

sequence = "I've been waiting for a HuggingFace course my whole life."

tokens = tokenizer.tokenize(sequence)
ids = tokenizer.convert_tokens_to_ids(tokens)
input_ids = torch.tensor(ids)
# This line will fail.
model(input_ids)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 14
#      12 input_ids = torch.tensor(ids)
#      13 # This line will fail.
# ---> 14 model(input_ids)
#
# File ~/miniforge3/envs/llm-learn/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/llm-learn/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniforge3/envs/llm-learn/lib/python3.13/site-packages/transformers/utils/generic.py:834, in can_return_tuple.<locals>.wrapper(self, *args, **kwargs)
#     832 if return_dict_passed is not None:
#     833     return_dict = return_dict_passed
# --> 834 output = func(self, *args, **kwargs)
#     835 if not return_dict and not isinstance(output, tuple):
#     836     output = output.to_tuple()
#
# File ~/miniforge3/envs/llm-learn/lib/python3.13/site-packages/transformers/models/distilbert/modeling_distilbert.py:585, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, inputs_embeds, labels, position_ids, **kwargs)
#     568 @can_return_tuple
#     569 @auto_docstring
#     570 def forward(
#    (...)    577     **kwargs: Unpack[TransformersKwargs],
#     578 ) -> SequenceClassifierOutput | tuple[torch.Tensor, ...]:
#     579     r"""
#     580     labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     581         Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     582         config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     583         `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     584     """
# --> 585     distilbert_output = self.distilbert(
#     586         input_ids=input_ids,
#     587         attention_mask=attention_mask,
#     588         inputs_embeds=inputs_embeds,
#     589         position_ids=position_ids,
#     590         return_dict=True,
#     591         **kwargs,
#     592     )
#     593     hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     594     pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File ~/miniforge3/envs/llm-learn/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/llm-learn/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniforge3/envs/llm-learn/lib/python3.13/site-packages/transformers/utils/generic.py:1001, in check_model_inputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#     999             outputs = func(self, *args, **kwargs)
#    1000     else:
# -> 1001         outputs = func(self, *args, **kwargs)
#    1002 except TypeError as original_exception:
#    1003     # If we get a TypeError, it's possible that the model is not receiving the recordable kwargs correctly.
#    1004     # Get a TypeError even after removing the recordable kwargs -> re-raise the original exception
#    1005     # Otherwise -> we're probably missing `**kwargs` in the decorated function
#    1006     kwargs_without_recordable = {k: v for k, v in kwargs.items() if k not in recordable_keys}
#
# File ~/miniforge3/envs/llm-learn/lib/python3.13/site-packages/transformers/models/distilbert/modeling_distilbert.py:410, in DistilBertModel.forward(self, input_ids, attention_mask, inputs_embeds, position_ids, **kwargs)
#     407 if (input_ids is None) ^ (inputs_embeds is not None):
#     408     raise ValueError("You must specify exactly one of input_ids or inputs_embeds")
# --> 410 embeddings = self.embeddings(input_ids, inputs_embeds, position_ids)
#     412 attention_mask = create_bidirectional_mask(
#     413     config=self.config,
#     414     input_embeds=embeddings,
#     415     attention_mask=attention_mask,
#     416 )
#     418 return self.transformer(
#     419     hidden_states=embeddings,
#     420     attention_mask=attention_mask,
#     421     **kwargs,
#     422 )
#
# File ~/miniforge3/envs/llm-learn/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/llm-learn/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniforge3/envs/llm-learn/lib/python3.13/site-packages/transformers/models/distilbert/modeling_distilbert.py:116, in Embeddings.forward(self, input_ids, input_embeds, position_ids)
#     112         position_ids = position_ids.unsqueeze(0).expand_as(input_ids)  # (bs, max_seq_length)
#     114 position_embeddings = self.position_embeddings(position_ids)  # (bs, max_seq_length, dim)
# --> 116 embeddings = input_embeds + position_embeddings  # (bs, max_seq_length, dim)
#     117 embeddings = self.LayerNorm(embeddings)  # (bs, max_seq_length, dim)
#     118 embeddings = self.dropout(embeddings)  # (bs, max_seq_length, dim)
#
# RuntimeError: The size of tensor a (14) must match the size of tensor b (512) at non-singleton dimension 1

# %%
tokenized_inputs = tokenizer(sequence, return_tensors="pt")
print(tokenized_inputs["input_ids"])
# Out:
# tensor([[  101,  1045,  1005,  2310,  2042,  3403,  2005,  1037, 17662, 12172,
#           2607,  2026,  2878,  2166,  1012,   102]])

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

checkpoint = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSequenceClassification.from_pretrained(checkpoint)

sequence = "I've been waiting for a HuggingFace course my whole life."

tokens = tokenizer.tokenize(sequence)
ids = tokenizer.convert_tokens_to_ids(tokens)

input_ids = torch.tensor([ids])
print("Input IDs:", input_ids)

output = model(input_ids)
print("Logits:", output.logits)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# Input IDs: tensor([[ 1045,  1005,  2310,  2042,  3403,  2005,  1037, 17662, 12172,  2607,
#           2026,  2878,  2166,  1012]])
# Logits: tensor([[-2.7276,  2.8789]], grad_fn=<AddmmBackward0>)

# %%
batched_ids = [
    [200, 200, 200],
    [200, 200]
]

# %%
padding_id = 100

batched_ids = [
    [200, 200, 200],
    [200, 200, padding_id],
]

# %%
model = AutoModelForSequenceClassification.from_pretrained(checkpoint)

sequence1_ids = [[200, 200, 200]]
sequence2_ids = [[200, 200]]
batched_ids = [
    [200, 200, 200],
    [200, 200, tokenizer.pad_token_id],
]

print(model(torch.tensor(sequence1_ids)).logits)
print(model(torch.tensor(sequence2_ids)).logits)
print(model(torch.tensor(batched_ids)).logits)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tensor([[ 1.5694, -1.3895]], grad_fn=<AddmmBackward0>)
# tensor([[ 0.5803, -0.4125]], grad_fn=<AddmmBackward0>)
# tensor([[ 1.5694, -1.3895],
#         [ 1.3374, -1.2163]], grad_fn=<AddmmBackward0>)

# %%
batched_ids = [
    [200, 200, 200],
    [200, 200, tokenizer.pad_token_id],
]

attention_mask = [
    [1, 1, 1],
    [1, 1, 0],
]

outputs = model(torch.tensor(batched_ids), attention_mask=torch.tensor(attention_mask))
print(outputs.logits)
# Out:
# tensor([[ 1.5694, -1.3895],
#         [ 0.5803, -0.4125]], grad_fn=<AddmmBackward0>)

# %%
sequence = sequence[:max_sequence_length]
