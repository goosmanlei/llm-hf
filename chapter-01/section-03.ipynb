# %% [markdown]
# # Transformers能做什么？

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
# !pip install datasets evaluate transformers[sentencepiece]

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.9598050713539124}]

# %%
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598050713539124},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %% [markdown]
# 目前 可用的一些pipeline 有：
#
# - eature-extraction （获取文本的向量表示）
# - fill-mask （完形填空）
# - ner （命名实体识别）
# - question-answering （问答）
# - sentiment-analysis （情感分析）
# - summarization （提取摘要）
# - text-generation （文本生成）
# - translation （翻译）
# - zero-shot-classification （零样本分类）

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445961475372314, 0.11197615414857864, 0.04342764988541603]}

# %%
from transformers import pipeline

generator = pipeline("text-generation")
generator("In this course, we will teach you how to")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: openai-community/gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Passing `generation_config` together with generation-related arguments=({'max_length', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "In this course, we will teach you how to work with your Python 3 project using Python.\n\nThe most basic way to learn Python is to build your project using PyQt. Before we start, let's start with a basic Python example.\n\n>>> import pyqt >>> python = pyqt('python') >>> import sys >>> sys.path = './pyqt_py.py' >>> >>> pyqt_py.py = sys.path\n\nThis example is a test project, and you should be able to run it with a standard Python interpreter.\n\nBefore we start, we will add the following line to our.py file:\n\nimport sys >>> sys.path = './pyqt_py.py'\n\nAnd we should be able to run it as a test project.\n\nNow that we've got a Python test project, we can start using it as a web server.\n\nTo run the test project, we will need to add the following lines to our.py file:\n\n#!/usr/bin/env python test_python.py # --no-check-for-error --class test_python.py # --no-check-for-error --class test_python_test # --"},
#  {'generated_text': 'In this course, we will teach you how to use the Java EE Platform for programming. In this course, you will learn the Java EE Platform, the Java EE framework, the Java EE API, and the Java EE JNI. You will learn how to create, configure, and deploy Java EE applications.\n\nProgramming is one of the most important fields of computer science. In this course we will teach you how to make Java EE applications. In this course, we will teach you how to use the Java EE Platform for programming. In this course, you will learn how to use the Java EE Platform for programming. In this course, you will learn how to use the Java EE Platform for programming.\n\nProgramming is a skill that is easily acquired easily, and not found in many other fields. We will learn how to make applications that are easy for people to create and use. You will learn how to create applications that are easy for people to create and use. You will learn how to make applications that are easy for people to create and use.\n\nIn this course, we will teach you how to use the Java EE Platform for programming. In this course, we will teach you how to use the Java EE Platform for programming.\n\nYou will learn how to use the Java EE Platform for'}]

# %%
generator("In this course, we will teach you how to", num_return_sequences=2, max_length=30)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "In this course, we will teach you how to control the flow of information through the Internet and help you manage your daily life and your productivity.\n\nYou will learn:\n\nWhat are your favorite websites?\n\nHow to manage your website's content and behavior\n\nHow to keep up with your most recent content\n\nHow to manage your online life\n\nHow to manage your email list\n\nHow to manage your social media accounts\n\nHow to manage your social media accounts\n\nHow to manage your blog posts\n\nHow to manage your blog posts\n\nHow to manage your social media accounts\n\nHow to manage your social media accounts\n\nHow to manage your blog posts\n\nHow to manage your social media accounts\n\nHow to manage your blog posts\n\nHow to manage your blogs\n\nHow to manage your social media accounts\n\nHow to manage your social media accounts\n\nHow to manage your blog posts\n\nHow to manage your social media accounts\n\nHow to manage your social media accounts\n\nHow to manage your blog posts\n\nHow to manage your social media accounts\n\nHow to manage your blog posts\n\nHow to manage your social media accounts\n\nHow to manage your blogs\n\nHow to manage your social media accounts\n\nHow to manage your blogs"},
#  {'generated_text': 'In this course, we will teach you how to use a single-word template in your projects to create high-quality, easy to use templates.\n\nHow to Use an Example Template\n\nThe first step in using an example template is to create the template using the template library. We will start with the basics of using the template library with the following code:\n\nimport { template } from \'./example\' ; use Example ;\n\nThis will create a template named example.html with the following content:\n\n< script src = "//example.com/template.min.js" > </ script >\n\nThe template will be run using the default template library.\n\nOnce you have created the template, we will need to set the variable that the template will run with:\n\nconst Example = require ( \'example\' ); var Example = require ( \'./example\' ); var ExampleTemplate = new Example ();\n\nWe should set the variable example.html to the path of the template.\n\n< script src = "//example.com/template.min.js" > </ script >\n\nFinally, we need to set the variable example.js to a script which will run the example and the example.html in the same directory.\n\nimport { example'}]

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="distilgpt2")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'In this course, we will teach you how to use an HTML5 document and other tools to create a document. This course is the first in our series of courses on HTML5. It will be a first for you to see HTML5 documentation, but we will show you how to use an HTML5 document and other tools to create a document. This course is the first in our series of courses on HTML5. It will be a first for you to see HTML5 documentation, but we will show you how to use an HTML5 document and other tools to create a document. This course is the first in our series of courses on HTML5. It will be a first for you to see HTML5 documentation, but we will show you how to use an HTML5 document and other tools to create a document. This course is the first in our series of courses on HTML5. It will be a first for you to see HTML5 documentation, but we will show you how to use an HTML5 document and other tools to create a document. This course is the first in our series of courses on HTML5. It will be a first for you to see HTML5 documentation, but we will show you how to use an HTML5 document and other tools to create a document. This course is the first in our series'},
#  {'generated_text': "In this course, we will teach you how to make a beautiful, beautiful dress. We can't go completely without it. We also will teach you how to make a beautiful and beautiful pair of shoes.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)

# %%
from transformers import pipeline

ner = pipeline("ner", grouped_entities=True)
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering")
question_answerer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn",
)

# %%
from transformers import pipeline

summarizer = pipeline("summarization")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of 
    graduates in traditional engineering disciplines such as mechanical, civil, 
    electrical, chemical, and aeronautical engineering declined, but in most of 
    the premier American universities engineering curricula now concentrate on 
    and encourage largely the study of engineering science. As a result, there 
    are declining offerings in engineering subjects dealing with infrastructure, 
    the environment, and related issues, and greater concentration on high 
    technology subjects, largely supporting increasingly complex scientific 
    developments. While the latter is important, it should not be at the expense 
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other 
    industrial countries in Europe and Asia, continue to encourage and advance 
    the teaching of engineering. Both China and India, respectively, graduate 
    six and eight times as many traditional engineers as does the United States. 
    Other industrial countries at minimum maintain their output, while America 
    suffers an increasingly serious decline in the number of engineering graduates 
    and a lack of well-educated engineers.
"""
)

# %%
from transformers import pipeline

translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")
