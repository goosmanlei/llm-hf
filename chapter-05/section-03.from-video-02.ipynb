# %%
from datasets import load_dataset

dataset = load_dataset("PolyAI/minds14", "all", split = "train")
# Out:
# all/train-00000-of-00002.parquet:   0%|          | 0.00/260M [00:00<?, ?B/s]
# all/train-00001-of-00002.parquet:   0%|          | 0.00/307M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8168 [00:00<?, ? examples/s]
# Dataset({
#     features: ['path', 'audio', 'transcription', 'english_transcription', 'intent_class', 'lang_id'],
#     num_rows: 8168
# })

# %%
dataset_pandas = dataset.to_pandas()
dataset_pandas.head()
# Out:
#                               path  \
# 0   cs-CZ~ATM_LIMIT/response_4.wav
# 1  cs-CZ~ATM_LIMIT/response_17.wav
# 2  cs-CZ~ATM_LIMIT/response_16.wav
# 3   cs-CZ~ATM_LIMIT/response_5.wav
# 4   cs-CZ~ATM_LIMIT/response_7.wav
#
#                                                audio  \
# 0  {'bytes': b'RIFF\x88\xad\x00\x00WAVEfmt \x12\x...
# 1  {'bytes': b'RIFF2 \x01\x00WAVEfmt \x12\x00\x00...
# 2  {'bytes': b'RIFF\x88\x85\x00\x00WAVEfmt \x12\x...
# 3  {'bytes': b'RIFFR\x91\x00\x00WAVEfmt \x12\x00\...
# 4  {'bytes': b'RIFF2\x98\x01\x00WAVEfmt \x12\x00\...
#
#                                        transcription  \
# 0  Dobrý den potřeboval bych zjistit jaký je maxi...
# 1  Dobrý den Budu si poprvé vybírat peníze z vaše...
# 2     Jaký je limit který si můžu vybrat z bankomatu
# 3             Kolik peněz si můžu vybrat z bankomatu
# 4  Dobrý den rád bych se vás zeptal Chtěl bych si...
#
#                                english_transcription  intent_class  lang_id
# ...

# %%
dataset_pandas['intent_class'].value_counts()
# Out:
# intent_class
# 0     654
# 1     627
# 7     608
# 6     601
# 4     598
# 3     596
# 11    596
# 5     580
# 13    577
# 9     562
# 12    562
# 8     551
# 10    549
# 2     507
# Name: count, dtype: int64
